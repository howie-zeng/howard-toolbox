# %%
# %%
from pathlib import Path

import pandas as pd

DATA_PATH = Path(
    r"S:\QR\hzeng\howard-toolbox\interview_notes\Sending\loan_panel.parquet"
)

loan_panel = pd.read_parquet(DATA_PATH)

print(f"Shape: {loan_panel.shape}")
print("\nColumns and dtypes:")
print(loan_panel.dtypes)
loan_panel.head()

print(loan_panel.columns)
# Out:
# Shape: (773046, 46)
#
# Columns and dtypes:
# loan_id                            object
# orig_dt                            object
# o_bal                             float64
# o_noterate                        float64
# o_term                              int32
# ofico                             float64
# orig_ltv                          float64
# orig_cltv                         float64
# dti                               float64
# purpose                            object
# occ_type                            int32
# prop_type                          object
# num_units                           int32
# num_borrower                       object
# channel                            object
# ft_buyer                           object
# doc_raw_new                        object
# dscr_ratio                        float64
# foreign_national                   object
# prod_type                          object
# io                                 object
# io_term                           float64
# pp_penalty                         object
# prepayment_penalty_term           float64
# state                              object
# msa                                object
# zip_prefix                         object
# lien                                int32
# deal_name                          object
# shelf                              object
# servicer                           object
# r_dt                               object
# age                               float64
# bal                               float64
# c_noterate                        float64
# status                             object
# mod                                object
# mod_ft_pay_dt                      object
# servicer_curr                      object
# r_dt_geo_code                      object
# r_dt_geo_type                      object
# orig_dt_geo_code                   object
# orig_dt_geo_type                   object
# hamp_eligible                      object
# mi_type                            object
# loan_in_eligible_disaster_area     object
# dtype: object
# Index(['loan_id', 'orig_dt', 'o_bal', 'o_noterate', 'o_term', 'ofico',
#        'orig_ltv', 'orig_cltv', 'dti', 'purpose', 'occ_type', 'prop_type',
#        'num_units', 'num_borrower', 'channel', 'ft_buyer', 'doc_raw_new',
#        'dscr_ratio', 'foreign_national', 'prod_type', 'io', 'io_term',
#        'pp_penalty', 'prepayment_penalty_term', 'state', 'msa', 'zip_prefix',
#        'lien', 'deal_name', 'shelf', 'servicer', 'r_dt', 'age', 'bal',
#        'c_noterate', 'status', 'mod', 'mod_ft_pay_dt', 'servicer_curr',
#        'r_dt_geo_code', 'r_dt_geo_type', 'orig_dt_geo_code',
#        'orig_dt_geo_type', 'hamp_eligible', 'mi_type',
#        'loan_in_eligible_disaster_area'],
#       dtype='object')

# %%
# Examine the distribution of 'doc_raw_new' for rows where 'orig_cltv' is 0
zero_cltv_docs = loan_panel.loc[loan_panel['orig_cltv'] <= 1, 'doc_raw_new']
print(zero_cltv_docs.value_counts())
# Out:
# doc_raw_new
# Other                 49135
# FULL                  47072
# DSCR                  44126
# 1YDoc                 25684
# InvestorProperty      21209
# BankStatement         16042
# 2YDoc                 10199
#  other                 8626
#  dscr                  8206
#  full                  7776
# VOE                    6999
#  1ydoc                 4670
#  investorproperty      4063
# SelfEMp                3636
#  bankstatement         2585
# CPA                    2353
# Emp                    2297
# Asset                  2057
#  2ydoc                 1677
#  voe                   1192
# 2YDocA                  899
#  emp                    560
#  asset                  426
#  selfemp                309
#  cpa                    207
#  2ydoca                 136
#  forei                  119
#  tax                     46
# FOREI                    44
# Name: count, dtype: int64
